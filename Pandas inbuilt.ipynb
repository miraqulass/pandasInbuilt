# %%
import pandas as pd
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
df1 = sns.load_dataset('tips')

# %%
df2 = pd.read_csv('204.ece.csv')

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df2
# Out:
#       Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 0           ECTA.S19A1  2001.03         NaN         NaN      C  Dollars
# 1           ECTA.S19A1  2002.03         NaN         NaN      C  Dollars
# 2           ECTA.S19A1  2003.03         NaN         NaN      C  Dollars
# 3           ECTA.S19A1  2004.03     28005.1         NaN      F  Dollars
# 4           ECTA.S19A1  2005.03     30629.6         NaN      F  Dollars
# ...                ...      ...         ...         ...    ...      ...
# 16025       ECTQ.S4AXP  2018.03        47.2         NaN      F  Percent
# 16026       ECTQ.S4AXP  2018.06        48.6         NaN      F  Percent
# 16027       ECTQ.S4AXP  2018.09        48.2         NaN      F  Percent
# 16028       ECTQ.S4AXP  2018.12        46.6         NaN      F  Percent
# 16029       ECTQ.S4AXP  2019.03        45.8         NaN      F  Percent
#
#        Magnitude                                        Subject  \
# 0              6  Electronic Card Transactions (ANZSIC06) - ECT
# 1              6  Electronic Card Transactions (ANZSIC06) - ECT
# 2              6  Electronic Card Transactions (ANZSIC06) - ECT
# 3              6  Electronic Card Transactions (ANZSIC06) - ECT
# 4              6  Electronic Card Transactions (ANZSIC06) - ECT
# ...          ...                                            ...
# 16025          0  Electronic Card Transactions (ANZSIC06) - ECT
# 16026          0  Electronic Card Transactions (ANZSIC06) - ECT
# 16027          0  Electronic Card Transactions (ANZSIC06) - ECT
# 16028          0  Electronic Card Transactions (ANZSIC06) - ECT
# 16029          0  Electronic Card Transactions (ANZSIC06) - ECT
#
#                                                    Group Series_title_1  \
# 0      Total values - Electronic card transactions A/...         Actual
# 1      Total values - Electronic card transactions A/...         Actual
# 2      Total values - Electronic card transactions A/...         Actual
# 3      Total values - Electronic card transactions A/...         Actual
# 4      Total values - Electronic card transactions A/...         Actual
# ...                                                  ...            ...
# 16025  Electronic card transactions by mean and propo...         Actual
# 16026  Electronic card transactions by mean and propo...         Actual
# 16027  Electronic card transactions by mean and propo...         Actual
# 16028  Electronic card transactions by mean and propo...         Actual
# 16029  Electronic card transactions by mean and propo...         Actual
#
#                                           Series_title_2  Series_title_3  \
# 0                                   RTS total industries             NaN
# 1                                   RTS total industries             NaN
# 2                                   RTS total industries             NaN
# 3                                   RTS total industries             NaN
# 4                                   RTS total industries             NaN
# ...                                                  ...             ...
# 16025  Debit card usage as a proportion of total ECT ...  Proportion (%)
# 16026  Debit card usage as a proportion of total ECT ...  Proportion (%)
# 16027  Debit card usage as a proportion of total ECT ...  Proportion (%)
# 16028  Debit card usage as a proportion of total ECT ...  Proportion (%)
# 16029  Debit card usage as a proportion of total ECT ...  Proportion (%)
#
#        Series_title_4  Series_title_5
# 0                 NaN             NaN
# 1                 NaN             NaN
# 2                 NaN             NaN
# 3                 NaN             NaN
# 4                 NaN             NaN
# ...               ...             ...
# 16025             NaN             NaN
# 16026             NaN             NaN
# 16027             NaN             NaN
# 16028             NaN             NaN
# 16029             NaN             NaN
#
# [16030 rows x 14 columns]

# %%
x1 = np.random.rand(100,5)

# %%
x2 = np.random.rand(10,5)

# %%
df3 = pd.DataFrame(x1, columns = ['a', 'b', 'c', 'd', 'e'])

# %%
df3
# Out:
#            a         b         c         d         e
# 0   0.131221  0.914997  0.056479  0.516794  0.789116
# 1   0.383363  0.605543  0.102337  0.716176  0.496195
# 2   0.209308  0.566644  0.677357  0.887982  0.430045
# 3   0.931610  0.459887  0.706054  0.835081  0.059226
# 4   0.645430  0.397942  0.234468  0.809104  0.771068
# ..       ...       ...       ...       ...       ...
# 95  0.999950  0.412641  0.623994  0.563892  0.654840
# 96  0.586375  0.263748  0.300842  0.637652  0.821319
# 97  0.518583  0.220160  0.420744  0.229272  0.155612
# 98  0.005914  0.869521  0.379030  0.679235  0.823058
# 99  0.887774  0.401916  0.762782  0.299582  0.531483
#
# [100 rows x 5 columns]

# %%
df4 = pd.DataFrame(x2, columns = ['a', 'b', 'c', 'd', 'e'])

# %%
df4
# Out:
#           a         b         c         d         e
# 0  0.557025  0.808327  0.999549  0.758139  0.159596
# 1  0.167759  0.413508  0.227039  0.487773  0.475503
# 2  0.228357  0.659403  0.624061  0.521147  0.780486
# 3  0.497974  0.853719  0.831085  0.818870  0.183272
# 4  0.075562  0.998210  0.029122  0.796188  0.100383
# 5  0.801427  0.778244  0.446435  0.950177  0.992939
# 6  0.094669  0.185850  0.830493  0.983066  0.216688
# 7  0.000595  0.778006  0.989712  0.524261  0.980787
# 8  0.168008  0.387932  0.832953  0.387339  0.241203
# 9  0.131981  0.288767  0.102640  0.797754  0.378140

# %%
# Point plots

# %%
df3.plot.scatter(x='a', y='b')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df4.plot.scatter(x='a', y='b')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df2.plot.scatter(x='Series_title_1', y='Period')
# Out:
# <AxesSubplot:xlabel='Series_title_1', ylabel='Period'>

# %%
df1.plot.scatter(x='total_bill', y='tip')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
# Line Plots

# %%
df4.plot.line()
# Out:
# <AxesSubplot:>

# %%
df3.plot.line()
# Out:
# <AxesSubplot:>

# %%
df2.plot.line()
# Out:
# <AxesSubplot:>

# %%
df1.plot.line()
# Out:
# <AxesSubplot:>

# %%
# KDE plots

# %%
df4.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df3.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df2.plot.kde()
# Out:
# /home/miraqulas/anaconda3/lib/python3.9/site-packages/pandas/plotting/_matplotlib/hist.py:184: RuntimeWarning: All-NaN slice encountered
#   sample_range = np.nanmax(y) - np.nanmin(y)
# /home/miraqulas/anaconda3/lib/python3.9/site-packages/pandas/plotting/_matplotlib/hist.py:186: RuntimeWarning: All-NaN slice encountered
#   np.nanmin(y) - 0.5 * sample_range,
# /home/miraqulas/anaconda3/lib/python3.9/site-packages/pandas/plotting/_matplotlib/hist.py:187: RuntimeWarning: All-NaN slice encountered
#   np.nanmax(y) + 0.5 * sample_range,
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_22252/2798605528.py in <module>
# ----> 1 df2.plot.kde()
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/plotting/_core.py in kde(self, bw_method, ind, **kwargs)
#    1452             >>> ax = df.plot.kde(ind=[1, 2, 3, 4, 5, 6])
#    1453         """
# -> 1454         return self(kind="kde", bw_method=bw_method, ind=ind, **kwargs)
#    1455
#    1456     density = kde
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     327         self._compute_plot_data()
#     328         self._setup_subplots()
# --> 329         self._make_plot()
#     330         self._add_table()
#     331         self._make_legend()
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/plotting/_matplotlib/hist.py in _make_plot(self)
#     138                 kwds["weights"] = weights[:, i]
#     139
# --> 140             artists = self._plot(ax, y, column_num=i, stacking_id=stacking_id, **kwds)
#     141
#     142             # when by is applied, show title for subplots to know which group it is
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/plotting/_matplotlib/hist.py in _plot(cls, ax, y, style, bw_method, ind, column_num, stacking_id, **kwds)
#     214
#     215         y = remove_na_arraylike(y)
# --> 216         gkde = gaussian_kde(y, bw_method=bw_method)
#     217
#     218         y = gkde.evaluate(ind)
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/stats/_kde.py in __init__(self, dataset, bw_method, weights)
#     192         self.dataset = atleast_2d(asarray(dataset))
#     193         if not self.dataset.size > 1:
# --> 194             raise ValueError("`dataset` input should have multiple elements.")
#     195
#     196         self.d, self.n = self.dataset.shape
#
# ValueError: `dataset` input should have multiple elements.

# %%
df1.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# Distribution Plots
#     hist plot
#     bar graph
#     area plot

# %%
df1.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df2.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df3.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df4.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar()

# %%
df4 = pd.read_csv('188.iris.csv')

# %%
df4
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]
