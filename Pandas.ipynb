# %%
import pandas as pd
import numpy as np

# %%
l = [i for i in range(5)]

# %%
s = pd.Series(l)

# %%
s
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %%
s = pd.Series(l, index = ['a','b','c','d','e'])

# %%
s
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# dtype: int64

# %%
df = pd.read_csv('187.tips.csv')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df = pd.read_csv('187.tips.csv', chunksize = 2)

# %%
for chunk in df:
    print(chunk)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
#    total_bill   tip   sex smoker  day    time  size
# 2       21.01  3.50  Male     No  Sun  Dinner     3
# 3       23.68  3.31  Male     No  Sun  Dinner     2
#    total_bill   tip     sex smoker  day    time  size
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
#    total_bill   tip   sex smoker  day    time  size
# 6        8.77  2.00  Male     No  Sun  Dinner     2
# 7       26.88  3.12  Male     No  Sun  Dinner     4
#    total_bill   tip   sex smoker  day    time  size
# 8       15.04  1.96  Male     No  Sun  Dinner     2
# 9       14.78  3.23  Male     No  Sun  Dinner     2
#     total_bill   tip     sex smoker  day    time  size
# 10       10.27  1.71    Male     No  Sun  Dinner     2
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# ...

# %%
chunk
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_95521/964094849.py in <module>
# ----> 1 df.head()
#
# AttributeError: 'TextFileReader' object has no attribute 'head'

# %%
df = pd.read_csv('187.tips.csv')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df = df[df['size']>2]

# %%
df
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 1         10.34  1.66    Male     No  Sun  Dinner     3
# 2         21.01  3.50    Male     No  Sun  Dinner     3
# 4         24.59  3.61  Female     No  Sun  Dinner     4
# 5         25.29  4.71    Male     No  Sun  Dinner     4
# 7         26.88  3.12    Male     No  Sun  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 227       20.45  3.00    Male     No  Sat  Dinner     4
# 230       24.01  2.00    Male    Yes  Sat  Dinner     4
# 231       15.69  3.00    Male    Yes  Sat  Dinner     3
# 238       35.83  4.67  Female     No  Sat  Dinner     3
# 239       29.03  5.92    Male     No  Sat  Dinner     3
#
# [84 rows x 7 columns]

# %%
df = df[df['sex']=='Male']

# %%
df
# Out:
#      total_bill    tip   sex smoker   day    time  size
# 1         10.34   1.66  Male     No   Sun  Dinner     3
# 2         21.01   3.50  Male     No   Sun  Dinner     3
# 5         25.29   4.71  Male     No   Sun  Dinner     4
# 7         26.88   3.12  Male     No   Sun  Dinner     4
# 13        18.43   3.00  Male     No   Sun  Dinner     4
# 17        16.29   3.71  Male     No   Sun  Dinner     3
# 19        20.65   3.35  Male     No   Sat  Dinner     3
# 23        39.42   7.58  Male     No   Sat  Dinner     4
# 25        17.81   2.34  Male     No   Sat  Dinner     4
# 31        18.35   2.50  Male     No   Sat  Dinner     4
# 35        24.06   3.60  Male     No   Sat  Dinner     3
# 36        16.31   2.00  Male     No   Sat  Dinner     3
# 38        18.69   2.31  Male     No   Sat  Dinner     3
# 39        31.27   5.00  Male     No   Sat  Dinner     3
# 40        16.04   2.24  Male     No   Sat  Dinner     3
# 44        30.40   5.60  Male     No   Sun  Dinner     4
# ...

# %%
s
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# dtype: int64

# %%
pd.skew(s)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_95521/3532171054.py in <module>
# ----> 1 pd.skew(s)
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/__init__.py in __getattr__(name)
#     259         return _SparseArray
#     260
# --> 261     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     262
#     263
#
# AttributeError: module 'pandas' has no attribute 'skew'

# %%
r = pd.read_csv('187.tips.csv')

# %%
r.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
j = pd.read_csv('data.json')

# %%
j.head()
# Out:
# Empty DataFrame
# ...

# %%
bloodType = pd.Series(['a+','b-','ab+','ab-','o+','o-','a+','a-','ab-','ab+','o-','o+','b-','b+','a+','a+'], 
                      dtype = 'category')

# %%
bloodType
# Out:
# 0      a+
# 1      b-
# 2     ab+
# 3     ab-
# 4      o+
# 5      o-
# 6      a+
# 7      a-
# 8     ab-
# 9     ab+
# 10     o-
# 11     o+
# 12     b-
# 13     b+
# 14     a+
# 15     a+
# dtype: category
# Categories (8, object): ['a+', 'a-', 'ab+', 'ab-', 'b+', 'b-', 'o+', 'o-']

# %%
df = pd.DataFrame({'A':['a','b','c','a']})

# %%
df['B']= df['A'].astype('category')

# %%
df
# Out:
#    A  B
# 0  a  a
# 1  b  b
# 2  c  c
# 3  a  a

# %%
df = pd.DataFrame({'value':np.random.randint(0,100,20)})

# %%
labels = ['{0}-{1}'.format(i, i + 9)for i in range(0,100,10)]

# %%
df["group"] = pd.cut(df.value, range(0, 105, 10), right=False, labels=labels)

# %%
df.head(10)
# Out:
#    value  group
# 0     20  20-29
# 1     68  60-69
# 2     63  60-69
# 3     65  60-69
# 4     28  20-29
# 5     86  80-89
# 6     14  10-19
# 7     35  30-39
# 8     22  20-29
# 9     87  80-89

# %%
df.head(20)
# Out:
#     value  group
# 0      20  20-29
# 1      68  60-69
# 2      63  60-69
# 3      65  60-69
# 4      28  20-29
# 5      86  80-89
# 6      14  10-19
# 7      35  30-39
# 8      22  20-29
# 9      87  80-89
# 10     54  50-59
# 11     37  30-39
# 12     55  50-59
# 13     81  80-89
# 14     56  50-59
# 15     98  90-99
# 16     22  20-29
# 17     52  50-59
# 18     38  30-39
# 19     24  20-29

# %%
raw = pd.Categorical(
    ["a", "b", "c", "a"], categories=["b", "c", "d"], ordered=False
)

# %%
s = pd.Series(raw)

# %%
s
# Out:
# 0    NaN
# 1      b
# 2      c
# 3    NaN
# dtype: category
# Categories (3, object): ['b', 'c', 'd']

# %%
df = pd.DataFrame({'A':['a','b','c','a']})

# %%
df['B'] = raw

# %%
df
# Out:
#    A    B
# 0  a  NaN
# 1  b    b
# 2  c    c
# 3  a  NaN

# %%
df.dtypes
# Out:
# A      object
# B    category
# dtype: object

# %%
df = pd.DataFrame({'A': list('abca'), 'B': list('bccd')}, dtype = 'category')

# %%
df
# Out:
#    A  B
# 0  a  b
# 1  b  c
# 2  c  c
# 3  a  d

# %%
df_cat = df.astype('category')

# %%
df_cat['A']
# Out:
# 0    a
# 1    b
# 2    c
# 3    a
# Name: A, dtype: category
# Categories (3, object): ['a', 'b', 'c']

# %%
s = pd.Series(list('abcde'))

# %%
s
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# dtype: object

# %%
from pandas.api.types import CategoricalDtype

# %%
CategoricalDtype(list('abcde'))
# Out:
# CategoricalDtype(categories=['a', 'b', 'c', 'd', 'e'], ordered=False)
